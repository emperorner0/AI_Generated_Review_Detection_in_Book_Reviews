# %% [markdown]
# # Importations

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm_notebook as tqdm

import torch
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from torchtext.data import Field, TabularDataset, BucketIterator, Iterator
import torch.nn as nn
import torch.nn.functional as F
import transformers
from transformers import AutoModel, BertTokenizerFast, AdamW
import torch.optim as optim
from torchsummary import summary

from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight

import plotly.express as px
import seaborn as sns

from interpret_text.experimental.unified_information import UnifiedInformationExplainer 

import time
import os
# Out:
# I1127 10:27:18.526971  8292 modeling.py:230] Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex .

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Save model functionality 
save = False

# %% [markdown]
# # Helper Functions

# %%
def remove_over(df, leng = 512, target='reviews', labels='label'):
    '''Checks text length for being over 512 tokens, 
    which bert-base does not support.'''
    seq_list = []
    seq_len = [len(i.split()) for i in df[target]]
    ugh = []
    for x, y in enumerate(seq_len):
        if y > leng:
            ugh.append(x)
            
    df_tuple = zip(df[target], df[labels])
    
    for x, text in enumerate(df_tuple):
        if x not in ugh:
            seq_list.append(text)
            
    seq_df = pd.DataFrame(seq_list, columns=['reviews','label'])
    
    return seq_df

# %% [markdown]
# # Data prep

# %% [markdown]
# Pulling in our generated fake reviews and our saved real reviews.
#
# Fake reviews are generated by a **GPT2** text generator tuned with **50,000** Amazon book reviews.

# %%
fake_rev = pd.read_csv('Data/reviewseries.csv')
real_rev = pd.read_csv('Data/realreviews.csv')
fake_rev.rename({'reviewText':'reviews'})
# Out:
#        Unnamed: 0                                            reviews  label
# 0           41830   So enjoyable!!! If you are a fan of the serie...      1
# 1           23419   This book brings together a lot of history an...      1
# 2           31825   Good work but I would have liked to see more ...      1
# 3           27356   (Im writing this review in the order it is re...      1
# 4            9883   excelente libro de hyenuk, en uno poco, cono ...      1
# ...           ...                                                ...    ...
# 49995       10505   Russells Introduction is a page-turner, and i...      1
# 49996       12747   Quick and easy ordering and shipping.  It arr...      1
# 49997       48702   Im used to hearing about a series by John Gri...      1
# 49998        7944   fun book. What a great ending for the series....      1
# 49999       18540   Just finished reading this.  I loved the char...      1
#
# [50000 rows x 3 columns]

# %%
fake_rev.drop('Unnamed: 0', inplace=True, axis=1) # Drop unneeded index

# %%
fake_rev # Sanity check
# Out:
#                                                  reviews  label
# 0       So enjoyable!!! If you are a fan of the serie...      1
# 1       This book brings together a lot of history an...      1
# 2       Good work but I would have liked to see more ...      1
# 3       (Im writing this review in the order it is re...      1
# 4       excelente libro de hyenuk, en uno poco, cono ...      1
# ...                                                  ...    ...
# 49995   Russells Introduction is a page-turner, and i...      1
# 49996   Quick and easy ordering and shipping.  It arr...      1
# 49997   Im used to hearing about a series by John Gri...      1
# 49998   fun book. What a great ending for the series....      1
# 49999   Just finished reading this.  I loved the char...      1
#
# [50000 rows x 2 columns]

# %%
real_rev.drop('Unnamed: 0', inplace=True, axis=1) # Drop unneeded index
real_rev['reviews'] = real_rev['reviewText'] # Rename work-around
real_rev.drop('reviewText', inplace=True, axis=1)

# %%
real_rev['label'] = 0 # Broadcast label for real-reviews
display(real_rev)
# Out:
#                                                  reviews  label
# 0      Great book.... Keeps you coming back for more....      0
# 1                                                Thanks!      0
# 2      Required text book for college English class. ...      0
# 3      The good thing about this book is i have got h...      0
# 4      First off Heather Dahlgren this is an amazing ...      0
# ...                                                  ...    ...
# 48703  Very interesting book. With a million new book...      0
# 48704  This was an excellent, grounded piece of liter...      0
# 48705  For this reader, Feverborn, the eighth of ten ...      0
# 48706  I have been enjoying each one of the Ruth Gall...      0
# 48707                                                  0      0
#
# [48708 rows x 2 columns]

# %%
review_df = pd.concat([real_rev, fake_rev], axis=0) # Join our two dataframes
review_df # sanity check concatenation
# Out:
#                                                  reviews  label
# 0      Great book.... Keeps you coming back for more....      0
# 1                                                Thanks!      0
# 2      Required text book for college English class. ...      0
# 3      The good thing about this book is i have got h...      0
# 4      First off Heather Dahlgren this is an amazing ...      0
# ...                                                  ...    ...
# 49995   Russells Introduction is a page-turner, and i...      1
# 49996   Quick and easy ordering and shipping.  It arr...      1
# 49997   Im used to hearing about a series by John Gri...      1
# 49998   fun book. What a great ending for the series....      1
# 49999   Just finished reading this.  I loved the char...      1
#
# [98708 rows x 2 columns]

# %%
review_df.sample(frac=1) # Shuffle dataframe
# Out:
#                                                  reviews  label
# 2828              Another great map by David E. Hargrave      1
# 2596    Upon receiving this product, I have been sear...      1
# 11269  Just like in "Normandy" by Antony Beevor, "Sta...      0
# 3449   This is a GREAT book.  I was excited to learn ...      0
# 16678  Cornwell is back on track with this one...have...      0
# ...                                                  ...    ...
# 16      Bought for Caregiver as a gift. I have now us...      1
# 18448  Such an amazing book this is. E.L. Todd is one...      0
# 18418  Bad boy comes home, investigates a cold case, ...      0
# 28674  I'm now into book 4 of this series, and these ...      0
# 24276   and interesting survey of history...I was ple...      1
#
# [98708 rows x 2 columns]

# %%
indexrange = list(range(len(review_df))) # Genereated list of integers for new index

# %%
review_df['newdex'] = indexrange # Assign index as new columns

# %%
review_df.set_index('newdex', inplace=True) # Swap to new index to avoid double assigned indices

# %%
review_df = review_df.sample(frac=1) # Shuffle on new index

# %%
review_df # Sanity check
# Out:
#                                                   reviews  label
# newdex
# 40972   This item was sent as a gift...I was thanked p...      0
# 26944   Jame's Ellroy's "LA Confidential" is a remarka...      0
# 8485    Reviewed by Suzanne and posted at Under The Co...      0
# 50648    At first I didnt want to read it because I lo...      1
# 98387    Read this book in one sitting.  It was amazin...      1
# ...                                                   ...    ...
# 70915    A very well-written novel.  It is very short ...      1
# 24182   Candace Robb has read and researched medieval ...      0
# 21632   Good Story, Entertaining and worth the $$$$. S...      0
# 74530    I was expecting a more serious read of the fi...      1
# 86395    Filled with lots of good tips and tricks for ...      1
#
# [98708 rows x 2 columns]

# %%
test = remove_over(review_df) # Using our helper function to cut review length

# %%
test # Sanity check
# Out:
#                                                  reviews  label
# 0      This item was sent as a gift...I was thanked p...      0
# 1      Jame's Ellroy's "LA Confidential" is a remarka...      0
# 2       At first I didnt want to read it because I lo...      1
# 3       Read this book in one sitting.  It was amazin...      1
# 4       I work as a software writer and have the abil...      1
# ...                                                  ...    ...
# 97366   A very well-written novel.  It is very short ...      1
# 97367  Candace Robb has read and researched medieval ...      0
# 97368  Good Story, Entertaining and worth the $$$$. S...      0
# 97369   I was expecting a more serious read of the fi...      1
# 97370   Filled with lots of good tips and tricks for ...      1
#
# [97371 rows x 2 columns]

# %%
if save:
    test.to_csv('Data/total_review_df.csv')

# %% [markdown]
# # Model Prep

# %% [markdown]
# ## Train-test split

# %%
# Train test split
train_text, temp_text, train_labels, temp_labels = train_test_split(test['reviews'], test['label'], 
                                                                    random_state=42, 
                                                                    test_size=0.3, 
                                                                    stratify=test['label'])

# %%
# Train test split our temp text/labels for a validation and test set
val_text, test_text, val_labels, test_labels = train_test_split(temp_text, temp_labels, 
                                                                random_state=42, 
                                                                test_size=0.5, 
                                                                stratify=temp_labels)

# %% [markdown]
# ## Model and tokenizer assignment
#
# ### Bookmark (BERT text here)

# %%
bert = AutoModel.from_pretrained('bert-base-uncased')

tokenizer = BertTokenizerFast.from_pretrained('bert-base-uncased')

# %% [markdown]
# ## Length Analysis

# %%
# Split sequences into 'tokens'
train_seq_len = [len(i.split()) for i in train_text]
val_seq_len = [len(i.split()) for i in val_text]
test_seq_len = [len(i.split()) for i in test_text]

# Average length of sequences
train_av = round(np.average(train_seq_len),3)
val_av = round(np.average(val_seq_len),3)
test_av = round(np.average(test_seq_len),3)
print('Average length of review:', train_av)
print('Average length of review:', val_av)
print('Average length of review:', test_av)

# Train historgram
fig, ax = plt.subplots()
plt.title('Train Histogram with Average Length')
plt.hist(pd.Series(train_seq_len), bins=30)
ax.axvline(train_av, color ='red', lw = 2, alpha = 0.75) 
plt.legend(['Average Length: {}'.format(train_av), 'Train Histogram'])
plt.show()

# Validation historgram
fig, ax = plt.subplots()
plt.title('Validation Histogram with Average Length')
plt.hist(pd.Series(val_seq_len), bins=30)
ax.axvline(train_av, color ='red', lw = 2, alpha = 0.75) 
plt.legend(['Average Length: {}'.format(val_av), 'Validation Histogram'])
plt.show()

# Testing historgram
fig, ax = plt.subplots()
plt.title('Test Histogram with Average Length')
plt.hist(pd.Series(test_seq_len), bins=30)
ax.axvline(train_av, color ='red', lw = 2, alpha = 0.75) 
plt.legend(['Average Length: {}'.format(test_av), 'Test Histogram'])
plt.show()
# Out:
# Average length of review: 73.254
# Average length of review: 72.858
# Average length of review: 73.277

# %% [markdown]
# ## Tokenization

# %% [markdown]
# ### Bookmark (Tokenizer text here)

# %%
# Using BERT Fast Tokenizer to encode text into input ids

# Training tokens
tokens_train = tokenizer.batch_encode_plus(
    train_text.tolist(),
    max_length = 80,
    padding=True,
    truncation=True
)

# Validation Tokens
tokens_val = tokenizer.batch_encode_plus(
    val_text.tolist(),
    max_length = 80,
    padding=True,
    truncation=True
)

# Testing tokens
tokens_test = tokenizer.batch_encode_plus(
    test_text.tolist(),
    max_length = 80,
    padding=True,
    truncation=True
)

# %%
# Store sequences, attention masks, and lables as torch tensors

# Train tensors
train_seq = torch.tensor(tokens_train['input_ids'])
train_mask = torch.tensor(tokens_train['attention_mask'])
train_y = torch.tensor(train_labels.tolist())

# Validation tensors
val_seq = torch.tensor(tokens_val['input_ids'])
val_mask = torch.tensor(tokens_val['attention_mask'])
val_y = torch.tensor(val_labels.tolist())

# Testing tensors
test_seq = torch.tensor(tokens_test['input_ids'])
test_mask = torch.tensor(tokens_test['attention_mask'])
test_y = torch.tensor(test_labels.tolist())

# %% [markdown]
# # Dataloaders

# %% [markdown]
# ## Bookmark (PyTorch dataloader text here)

# %%
batch = 128 # Batch size for datalaoder and subsequent model


# Training dataloader
train_data = TensorDataset(train_seq, train_mask, train_y)
train_sampler = RandomSampler(train_data)
train_loader = DataLoader(train_data, sampler=train_sampler, batch_size=batch)

# Validation dataloader
val_data = TensorDataset(val_seq, val_mask, val_y)
val_sampler = SequentialSampler(val_data)
val_loader = DataLoader(val_data, sampler = val_sampler, batch_size=batch)

# Testing dataloader
test_data = TensorDataset(test_seq, test_mask, test_y)
test_sampler = SequentialSampler(test_data)
test_loader = DataLoader(test_data, sampler = test_sampler, batch_size=batch)

# %% [markdown]
# # Model

# %% [markdown]
# ## Bookmark (Model description here)

# %%
# Freeze BERT Parameters
for param in bert.parameters():
    param.requires_grad = False

# %%
class BERT_Arch(nn.Module):
    
    def __init__(self, bert):
        '''
        Professional docstring here
        '''
        
        super(BERT_Arch, self).__init__()
        self.bert = bert
        
        self.droput = nn.Dropout(0.1)
        
        self.relu = nn.ReLU()
        
        self.lstm = nn.LSTM(768,512, bidirectional=True, num_layers=2, dropout=.1)
        self.bn = nn.BatchNorm1d(1024)
        self.fc1 = nn.Linear(1024,512)
        self.bn1 = nn.BatchNorm1d(512)
        self.fc2 = nn.Linear(512,256)
        self.bn2 = nn.BatchNorm1d(256)
        self.fc3 = nn.Linear(256,128)
        self.bn3 = nn.BatchNorm1d(128)
        self.fc4 = nn.Linear(128,2)
        
        self.softmax = nn.Softmax(dim=1)
        

    def forward(self, sent_id):
        '''
        Forward pass for model
        '''
        _, x = self.bert(sent_id)
        
        x = x.unsqueeze(0)
        x, _ = self.lstm(x)
        x = x.squeeze(0)
        x = self.bn(x)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.bn1(x)
        x = self.fc2(x)
        x = self.relu(x)
        x = self.bn2(x)
        x = self.fc3(x)
        x = self.relu(x)
        x = self.bn3(x)
        x = self.fc4(x)
        
        x = self.softmax(x)
        
        return x

# %% [markdown]
# ## Hyperparameters

# %% [markdown]
# ## Bookmark (AdamW text here)

# %%
# Model instantiation 
model = BERT_Arch(bert)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu') # Select device programatically
model = model.to(device) # Send model to device (GPU locally)

# AdamW optimizer
optimizer = AdamW(model.parameters(), lr = 2e-5) 

# Computation of class weights for training
class_weights = compute_class_weight('balanced', [0,1], train_labels)
print("Class Weights:",class_weights)
weights= torch.tensor(class_weights,dtype=torch.float)
weights = weights.to(device)

# Negative log-likelihood loss with weights passed
cross_entropy = nn.NLLLoss(weight=weights)
# Out:
# Class Weights: [1.02776019 0.9737    ]

# %% [markdown]
# ### Training Epochs

# %%
epochs = 50

# %%
# function to train the model
def train():
    """
    Future docstring
    """
    model.train()

    total_loss = 0
    total_accuracy = 0

    total_preds=[]
    total_acc=[]
    t0 = time.time()
    # iterate over batches
    for step, batch in enumerate(train_loader):
    
        if step % 100 == 0 and not step == 0:
          lapsed = time.time() - t0
          print('  Batch {:>5,}  of  {:>5,}.  Batch took {} secs'.format(step,
                                                                            len(train_loader),
                                                                            round(lapsed, 3)))

        # push the batch to gpu
        batch = [r.to(device) for r in batch]
        
        # Pulling apart batch
        sent_id, mask, labels = batch
        
        # Start model
        model.zero_grad()      
        preds = model(sent_id) #Get predictions
        loss = cross_entropy(preds, labels) # Passing through NNL for loss
        total_loss = total_loss + loss.item() # Collect total loss

        loss.backward() # Backpropagation
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0) #Clipping to avoid exploding grads
        optimizer.step() #Step AdamW
        
        preds_max = F.softmax(preds, dim=1) # Softmax to sum k-real vector to 1
        preds_max = torch.argmax(preds_max, dim=1) # Argmax pulls index of highest value
        wrong = torch.where(preds_max!=labels, # where to generate correct/incorrect tensor
                           torch.tensor([1.]).to(device),
                           torch.tensor([0.]).to(device))
        tot_wrong = int(torch.sum(wrong).detach().cpu()) # sum total incorrect for acc calc
        acc = 1 - tot_wrong/len(labels) # Normalized accuracy calculation
        total_acc.append(acc) # Appends accuracy 

        preds=preds.detach().cpu().numpy() # Send predictions to CPU
        total_preds.append(preds)
    
    # Epoch training loss
    avg_loss = total_loss / len(train_loader)
    total = time.time() - t0
    print('\nTime in seconds: {}'.format(round(total,3)))
    print('Average accuracy: {}'.format((np.average(total_acc))))
    

    
    total_preds  = np.concatenate(total_preds, axis=0)
    
    return avg_loss, total_preds, total_acc

# %%
# function for evaluating the model
def evaluate():
    
    """
    Future docstring
    """
    
    print("\nEvaluating...")
    t0 = time.time()
    # Evaluation mode
    model.eval()

    total_loss = 0
    total_accuracy = 0

    # Save predictions
    total_preds = []

    # iterate through loader
    for step,batch in enumerate(val_loader):
        if step % 100 == 0 and not step == 0:
            lapsed = time.time() - t0
            print('  Batch {:>5,}  of  {:>5,}. \n  Eval took {} secs'.format(step,
                                                                            len(val_loader),
                                                                            round(lapsed, 3)))
            
        batch = [t.to(device) for t in batch]
        sent_id, mask, labels = batch

        with torch.no_grad():
            # model predictions
            preds = model(sent_id)
            loss = cross_entropy(preds,labels)
            total_loss = total_loss + loss.item()
            preds = preds.detach().cpu().numpy()
            total_preds.append(preds)

    avg_loss = total_loss / len(val_loader) 
    total_preds  = np.concatenate(total_preds, axis=0)

    return avg_loss, total_preds

# %% [markdown]
# ## Training loop

# %% [markdown]
# ### Bookmark (Model training text here)

# %%
train_losses=[]
valid_losses=[]
total_acc = []
epoch_acc = []

best_valid_loss = float('inf')

for epoch in range(epochs):
    print('---------------------------------------------')
    print('Epoch {:} / {:}'.format(epoch + 1, epochs))
    print('---------------------------------------------')
    
    #train model
    train_loss, _, total_acc = train()

    #evaluate model
    valid_loss, _ = evaluate()
    
    epoch_acc.append(np.average(total_acc))
    
    #save the best model
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'Data/BERT_weights.pt')

    # append training and validation loss
    train_losses.append(abs(train_loss))
    valid_losses.append(abs(valid_loss))

    print('\n  Training Loss: {}'.format(abs(round(train_loss, 3))))
    print('  Validation Loss: {}'.format(abs(round(valid_loss, 3))))
print('\n------------------------')   
print('Finished')
print('------------------------')
# Out:
# ---------------------------------------------
# Epoch 1 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 35.991 secs
#   Batch   200  of    533.  Batch took 74.142 secs
#   Batch   300  of    533.  Batch took 112.241 secs
#   Batch   400  of    533.  Batch took 152.415 secs
#   Batch   500  of    533.  Batch took 189.9 secs
#
# Time in seconds: 202.395
# Average accuracy: 0.6585386793084963
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 36.357 secs
#
#   Training Loss: 0.638
#   Validation Loss: 0.674
# ---------------------------------------------
# Epoch 2 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 36.458 secs
#   Batch   200  of    533.  Batch took 72.311 secs
#   Batch   300  of    533.  Batch took 109.825 secs
#   Batch   400  of    533.  Batch took 145.83 secs
#   Batch   500  of    533.  Batch took 182.433 secs
#
# Time in seconds: 194.825
# Average accuracy: 0.7069711073140952
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 34.639 secs
#
#   Training Loss: 0.697
#   Validation Loss: 0.664
# ---------------------------------------------
# Epoch 3 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 38.052 secs
#   Batch   200  of    533.  Batch took 76.244 secs
#   Batch   300  of    533.  Batch took 112.612 secs
#   Batch   400  of    533.  Batch took 148.36 secs
#   Batch   500  of    533.  Batch took 186.304 secs
#
# Time in seconds: 198.558
# Average accuracy: 0.7167344638762322
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 34.77 secs
#
#   Training Loss: 0.711
#   Validation Loss: 0.665
# ---------------------------------------------
# Epoch 4 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 37.846 secs
#   Batch   200  of    533.  Batch took 73.106 secs
#   Batch   300  of    533.  Batch took 108.389 secs
#   Batch   400  of    533.  Batch took 143.622 secs
#   Batch   500  of    533.  Batch took 178.878 secs
#
# Time in seconds: 190.347
# Average accuracy: 0.722215940394294
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 33.767 secs
#
#   Training Loss: 0.717
#   Validation Loss: 0.69
# ---------------------------------------------
# Epoch 5 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 35.192 secs
#   Batch   200  of    533.  Batch took 71.394 secs
#   Batch   300  of    533.  Batch took 107.174 secs
#   Batch   400  of    533.  Batch took 143.91 secs
#   Batch   500  of    533.  Batch took 182.937 secs
#
# Time in seconds: 195.539
# Average accuracy: 0.7256751336400726
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 34.656 secs
#
#   Training Loss: 0.722
#   Validation Loss: 0.701
# ---------------------------------------------
# Epoch 6 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 36.474 secs
#   Batch   200  of    533.  Batch took 74.937 secs
#   Batch   300  of    533.  Batch took 112.137 secs
#   Batch   400  of    533.  Batch took 149.953 secs
#   Batch   500  of    533.  Batch took 187.737 secs
#
# Time in seconds: 199.622
# Average accuracy: 0.7299991251972959
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 33.869 secs
#
#   Training Loss: 0.727
#   Validation Loss: 0.703
# ---------------------------------------------
# Epoch 7 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 35.681 secs
#   Batch   200  of    533.  Batch took 71.163 secs
#   Batch   300  of    533.  Batch took 107.983 secs
#   Batch   400  of    533.  Batch took 143.396 secs
#   Batch   500  of    533.  Batch took 180.772 secs
#
# Time in seconds: 192.515
# Average accuracy: 0.729708299830251
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 34.557 secs
#
#   Training Loss: 0.728
#   Validation Loss: 0.722
# ---------------------------------------------
# Epoch 8 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 36.306 secs
#   Batch   200  of    533.  Batch took 72.623 secs
#   Batch   300  of    533.  Batch took 108.849 secs
#   Batch   400  of    533.  Batch took 145.065 secs
#   Batch   500  of    533.  Batch took 181.268 secs
#
# Time in seconds: 193.048
# Average accuracy: 0.7305584405431966
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 35.729 secs
#
#   Training Loss: 0.729
#   Validation Loss: 0.717
# ---------------------------------------------
# Epoch 9 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 36.218 secs
#   Batch   200  of    533.  Batch took 72.41 secs
#   Batch   300  of    533.  Batch took 109.938 secs
#   Batch   400  of    533.  Batch took 145.437 secs
#   Batch   500  of    533.  Batch took 180.796 secs
#
# Time in seconds: 192.299
# Average accuracy: 0.7357013963340183
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 33.784 secs
#
#   Training Loss: 0.734
#   Validation Loss: 0.643
# ---------------------------------------------
# Epoch 10 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 35.403 secs
#   Batch   200  of    533.  Batch took 70.745 secs
#   Batch   300  of    533.  Batch took 106.558 secs
#   Batch   400  of    533.  Batch took 143.063 secs
#   Batch   500  of    533.  Batch took 179.577 secs
#
# Time in seconds: 192.667
# Average accuracy: 0.7337056363352095
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 34.054 secs
#
#   Training Loss: 0.733
#   Validation Loss: 0.755
# ---------------------------------------------
# Epoch 11 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 37.929 secs
#   Batch   200  of    533.  Batch took 74.805 secs
#   Batch   300  of    533.  Batch took 111.849 secs
#   Batch   400  of    533.  Batch took 147.965 secs
#   Batch   500  of    533.  Batch took 183.958 secs
#
# Time in seconds: 195.544
# Average accuracy: 0.7345892801304387
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 34.333 secs
#
#   Training Loss: 0.733
#   Validation Loss: 0.769
# ---------------------------------------------
# Epoch 12 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 34.846 secs
#   Batch   200  of    533.  Batch took 69.641 secs
#   Batch   300  of    533.  Batch took 104.45 secs
#   Batch   400  of    533.  Batch took 139.36 secs
#   Batch   500  of    533.  Batch took 175.03 secs
#
# Time in seconds: 186.547
# Average accuracy: 0.7351595305101403
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 33.506 secs
#
#   Training Loss: 0.735
#   Validation Loss: 0.765
# ---------------------------------------------
# Epoch 13 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 35.535 secs
#   Batch   200  of    533.  Batch took 72.448 secs
#   Batch   300  of    533.  Batch took 108.921 secs
#   Batch   400  of    533.  Batch took 145.485 secs
#   Batch   500  of    533.  Batch took 180.887 secs
#
# Time in seconds: 192.196
# Average accuracy: 0.7373709666011495
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 33.645 secs
#
#   Training Loss: 0.736
#   Validation Loss: 0.647
# ---------------------------------------------
# Epoch 14 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 36.289 secs
#   Batch   200  of    533.  Batch took 72.273 secs
#   Batch   300  of    533.  Batch took 108.977 secs
#   Batch   400  of    533.  Batch took 145.239 secs
#   Batch   500  of    533.  Batch took 182.457 secs
#
# Time in seconds: 196.227
# Average accuracy: 0.738662696551416
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 38.952 secs
#
#   Training Loss: 0.738
#   Validation Loss: 0.757
# ---------------------------------------------
# Epoch 15 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 38.008 secs
#   Batch   200  of    533.  Batch took 75.967 secs
#   Batch   300  of    533.  Batch took 113.464 secs
#   Batch   400  of    533.  Batch took 152.059 secs
#   Batch   500  of    533.  Batch took 187.746 secs
#
# Time in seconds: 199.214
# Average accuracy: 0.7390437941123916
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 33.898 secs
#
#   Training Loss: 0.738
#   Validation Loss: 0.685
# ---------------------------------------------
# Epoch 16 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 34.975 secs
#   Batch   200  of    533.  Batch took 70.824 secs
#   Batch   300  of    533.  Batch took 105.94 secs
#   Batch   400  of    533.  Batch took 141.185 secs
#   Batch   500  of    533.  Batch took 177.275 secs
#
# Time in seconds: 188.664
# Average accuracy: 0.7376054881771346
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 33.858 secs
#
#   Training Loss: 0.737
#   Validation Loss: 0.709
# ---------------------------------------------
# Epoch 17 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 35.787 secs
#   Batch   200  of    533.  Batch took 71.483 secs
#   Batch   300  of    533.  Batch took 107.104 secs
#   Batch   400  of    533.  Batch took 142.759 secs
#   Batch   500  of    533.  Batch took 178.16 secs
#
# Time in seconds: 189.502
# Average accuracy: 0.7381487499627744
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 34.334 secs
#
#   Training Loss: 0.738
#   Validation Loss: 0.718
# ---------------------------------------------
# Epoch 18 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 35.686 secs
#   Batch   200  of    533.  Batch took 71.345 secs
#   Batch   300  of    533.  Batch took 107.739 secs
#   Batch   400  of    533.  Batch took 143.541 secs
#   Batch   500  of    533.  Batch took 178.702 secs
#
# Time in seconds: 191.286
# Average accuracy: 0.7403473897376337
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 35.377 secs
#
#   Training Loss: 0.739
#   Validation Loss: 0.637
# ---------------------------------------------
# Epoch 19 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 35.832 secs
#   Batch   200  of    533.  Batch took 71.064 secs
#   Batch   300  of    533.  Batch took 106.185 secs
#   Batch   400  of    533.  Batch took 141.442 secs
#   Batch   500  of    533.  Batch took 176.548 secs
#
# Time in seconds: 187.965
# Average accuracy: 0.7392178240120314
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 33.815 secs
#
#   Training Loss: 0.739
#   Validation Loss: 0.752
# ---------------------------------------------
# Epoch 20 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 37.684 secs
#   Batch   200  of    533.  Batch took 73.874 secs
#   Batch   300  of    533.  Batch took 109.207 secs
#   Batch   400  of    533.  Batch took 144.842 secs
#   Batch   500  of    533.  Batch took 180.489 secs
#
# Time in seconds: 192.236
# Average accuracy: 0.7405516654754459
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 35.002 secs
#
#   Training Loss: 0.74
#   Validation Loss: 0.673
# ---------------------------------------------
# Epoch 21 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 36.387 secs
#   Batch   200  of    533.  Batch took 71.81 secs
#   Batch   300  of    533.  Batch took 108.657 secs
#   Batch   400  of    533.  Batch took 144.885 secs
#   Batch   500  of    533.  Batch took 180.807 secs
#
# Time in seconds: 192.361
# Average accuracy: 0.7403629779773072
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 34.379 secs
#
#   Training Loss: 0.74
#   Validation Loss: 0.747
# ---------------------------------------------
# Epoch 22 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 35.244 secs
#   Batch   200  of    533.  Batch took 71.4 secs
#   Batch   300  of    533.  Batch took 108.353 secs
#   Batch   400  of    533.  Batch took 145.57 secs
#   Batch   500  of    533.  Batch took 182.121 secs
#
# Time in seconds: 193.956
# Average accuracy: 0.739686401843414
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 36.087 secs
#
#   Training Loss: 0.74
#   Validation Loss: 0.672
# ---------------------------------------------
# Epoch 23 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 37.855 secs
#   Batch   200  of    533.  Batch took 75.032 secs
#   Batch   300  of    533.  Batch took 116.199 secs
#   Batch   400  of    533.  Batch took 161.897 secs
#   Batch   500  of    533.  Batch took 204.828 secs
#
# Time in seconds: 218.611
# Average accuracy: 0.7422666044998363
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 38.998 secs
#
#   Training Loss: 0.741
#   Validation Loss: 0.697
# ---------------------------------------------
# Epoch 24 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 36.88 secs
#   Batch   200  of    533.  Batch took 76.187 secs
#   Batch   300  of    533.  Batch took 116.855 secs
#   Batch   400  of    533.  Batch took 155.323 secs
#   Batch   500  of    533.  Batch took 191.65 secs
#
# Time in seconds: 203.808
# Average accuracy: 0.7409634741951815
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 36.469 secs
#
#   Training Loss: 0.74
#   Validation Loss: 0.767
# ---------------------------------------------
# Epoch 25 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 39.451 secs
#   Batch   200  of    533.  Batch took 78.109 secs
#   Batch   300  of    533.  Batch took 116.214 secs
#   Batch   400  of    533.  Batch took 152.113 secs
#   Batch   500  of    533.  Batch took 187.751 secs
#
# Time in seconds: 200.467
# Average accuracy: 0.7425620830727538
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 34.693 secs
#
#   Training Loss: 0.742
#   Validation Loss: 0.768
# ---------------------------------------------
# Epoch 26 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 35.888 secs
#   Batch   200  of    533.  Batch took 73.564 secs
#   Batch   300  of    533.  Batch took 109.713 secs
#   Batch   400  of    533.  Batch took 145.685 secs
#   Batch   500  of    533.  Batch took 181.843 secs
#
# Time in seconds: 194.245
# Average accuracy: 0.7393411339676584
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 34.309 secs
#
#   Training Loss: 0.739
#   Validation Loss: 0.684
# ---------------------------------------------
# Epoch 27 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 36.542 secs
#   Batch   200  of    533.  Batch took 75.074 secs
#   Batch   300  of    533.  Batch took 111.895 secs
#   Batch   400  of    533.  Batch took 148.149 secs
#   Batch   500  of    533.  Batch took 183.716 secs
#
# Time in seconds: 195.028
# Average accuracy: 0.744526201271628
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 34.389 secs
#
#   Training Loss: 0.744
#   Validation Loss: 0.736
# ---------------------------------------------
# Epoch 28 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 35.758 secs
#   Batch   200  of    533.  Batch took 71.765 secs
#   Batch   300  of    533.  Batch took 108.181 secs
#   Batch   400  of    533.  Batch took 144.392 secs
#   Batch   500  of    533.  Batch took 180.406 secs
#
# Time in seconds: 192.268
# Average accuracy: 0.7408017752911046
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 33.606 secs
#
#   Training Loss: 0.74
#   Validation Loss: 0.773
# ---------------------------------------------
# Epoch 29 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 35.782 secs
#   Batch   200  of    533.  Batch took 72.029 secs
#   Batch   300  of    533.  Batch took 108.144 secs
#   Batch   400  of    533.  Batch took 144.124 secs
#   Batch   500  of    533.  Batch took 179.887 secs
#
# Time in seconds: 191.534
# Average accuracy: 0.7439957358021383
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 34.141 secs
#
#   Training Loss: 0.744
#   Validation Loss: 0.67
# ---------------------------------------------
# Epoch 30 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 36.645 secs
#   Batch   200  of    533.  Batch took 72.223 secs
#   Batch   300  of    533.  Batch took 108.137 secs
#   Batch   400  of    533.  Batch took 143.642 secs
#   Batch   500  of    533.  Batch took 179.175 secs
#
# Time in seconds: 190.815
# Average accuracy: 0.7423124385776825
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 33.926 secs
#
#   Training Loss: 0.742
#   Validation Loss: 0.694
# ---------------------------------------------
# Epoch 31 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 36.593 secs
#   Batch   200  of    533.  Batch took 72.248 secs
#   Batch   300  of    533.  Batch took 108.081 secs
#   Batch   400  of    533.  Batch took 143.929 secs
#   Batch   500  of    533.  Batch took 179.792 secs
#
# Time in seconds: 191.376
# Average accuracy: 0.7445839010244498
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 34.358 secs
#
#   Training Loss: 0.744
#   Validation Loss: 0.713
# ---------------------------------------------
# Epoch 32 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 36.155 secs
#   Batch   200  of    533.  Batch took 71.875 secs
#   Batch   300  of    533.  Batch took 107.43 secs
#   Batch   400  of    533.  Batch took 143.475 secs
#   Batch   500  of    533.  Batch took 179.833 secs
#
# Time in seconds: 191.627
# Average accuracy: 0.7420925746001965
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 33.641 secs
#
#   Training Loss: 0.742
#   Validation Loss: 0.699
# ---------------------------------------------
# Epoch 33 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 35.924 secs
#   Batch   200  of    533.  Batch took 71.122 secs
#   Batch   300  of    533.  Batch took 106.331 secs
#   Batch   400  of    533.  Batch took 142.059 secs
#   Batch   500  of    533.  Batch took 177.745 secs
#
# Time in seconds: 189.161
# Average accuracy: 0.7448472724768457
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 34.23 secs
#
#   Training Loss: 0.744
#   Validation Loss: 0.694
# ---------------------------------------------
# Epoch 34 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 35.28 secs
#   Batch   200  of    533.  Batch took 70.79 secs
#   Batch   300  of    533.  Batch took 106.402 secs
#   Batch   400  of    533.  Batch took 142.098 secs
#   Batch   500  of    533.  Batch took 177.701 secs
#
# Time in seconds: 189.254
# Average accuracy: 0.7422235623455136
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 34.367 secs
#
#   Training Loss: 0.742
#   Validation Loss: 0.689
# ---------------------------------------------
# Epoch 35 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 36.379 secs
#   Batch   200  of    533.  Batch took 72.451 secs
#   Batch   300  of    533.  Batch took 108.428 secs
#   Batch   400  of    533.  Batch took 145.29 secs
#   Batch   500  of    533.  Batch took 181.635 secs
#
# Time in seconds: 193.347
# Average accuracy: 0.7456543710354686
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 34.308 secs
#
#   Training Loss: 0.746
#   Validation Loss: 0.77
# ---------------------------------------------
# Epoch 36 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 36.387 secs
#   Batch   200  of    533.  Batch took 73.177 secs
#   Batch   300  of    533.  Batch took 108.666 secs
#   Batch   400  of    533.  Batch took 144.911 secs
#   Batch   500  of    533.  Batch took 180.31 secs
#
# Time in seconds: 192.119
# Average accuracy: 0.7478790687632151
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 34.468 secs
#
#   Training Loss: 0.747
#   Validation Loss: 0.771
# ---------------------------------------------
# Epoch 37 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 36.082 secs
#   Batch   200  of    533.  Batch took 71.84 secs
#   Batch   300  of    533.  Batch took 107.873 secs
#   Batch   400  of    533.  Batch took 143.368 secs
#   Batch   500  of    533.  Batch took 179.18 secs
#
# Time in seconds: 190.667
# Average accuracy: 0.7455210566872152
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 34.452 secs
#
#   Training Loss: 0.745
#   Validation Loss: 0.72
# ---------------------------------------------
# Epoch 38 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 35.428 secs
#   Batch   200  of    533.  Batch took 70.711 secs
#   Batch   300  of    533.  Batch took 106.213 secs
#   Batch   400  of    533.  Batch took 142.091 secs
#   Batch   500  of    533.  Batch took 177.858 secs
#
# Time in seconds: 189.6
# Average accuracy: 0.746208102534322
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 34.147 secs
#
#   Training Loss: 0.746
#   Validation Loss: 0.732
# ---------------------------------------------
# Epoch 39 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 35.344 secs
#   Batch   200  of    533.  Batch took 71.002 secs
#   Batch   300  of    533.  Batch took 108.394 secs
#   Batch   400  of    533.  Batch took 144.924 secs
#   Batch   500  of    533.  Batch took 180.708 secs
#
# Time in seconds: 192.174
# Average accuracy: 0.7495542228773936
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 33.518 secs
#
#   Training Loss: 0.749
#   Validation Loss: 0.691
# ---------------------------------------------
# Epoch 40 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 36.3 secs
#   Batch   200  of    533.  Batch took 71.318 secs
#   Batch   300  of    533.  Batch took 106.477 secs
#   Batch   400  of    533.  Batch took 141.347 secs
#   Batch   500  of    533.  Batch took 176.381 secs
#
# Time in seconds: 187.777
# Average accuracy: 0.7482648195300634
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 33.315 secs
#
#   Training Loss: 0.748
#   Validation Loss: 0.729
# ---------------------------------------------
# Epoch 41 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 35.492 secs
#   Batch   200  of    533.  Batch took 71.162 secs
#   Batch   300  of    533.  Batch took 106.712 secs
#   Batch   400  of    533.  Batch took 141.916 secs
#   Batch   500  of    533.  Batch took 176.785 secs
#
# Time in seconds: 188.506
# Average accuracy: 0.7464912501116769
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 34.007 secs
#
#   Training Loss: 0.746
#   Validation Loss: 0.736
# ---------------------------------------------
# Epoch 42 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 35.721 secs
#   Batch   200  of    533.  Batch took 71.505 secs
#   Batch   300  of    533.  Batch took 106.805 secs
#   Batch   400  of    533.  Batch took 142.429 secs
#   Batch   500  of    533.  Batch took 179.562 secs
#
# Time in seconds: 191.467
# Average accuracy: 0.7466529490157539
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 35.268 secs
#
#   Training Loss: 0.746
#   Validation Loss: 0.687
# ---------------------------------------------
# Epoch 43 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 37.221 secs
#   Batch   200  of    533.  Batch took 73.398 secs
#   Batch   300  of    533.  Batch took 109.185 secs
#   Batch   400  of    533.  Batch took 144.803 secs
#   Batch   500  of    533.  Batch took 184.228 secs
#
# Time in seconds: 197.064
# Average accuracy: 0.7477448237737871
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 35.872 secs
#
#   Training Loss: 0.748
#   Validation Loss: 0.705
# ---------------------------------------------
# Epoch 44 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 35.689 secs
#   Batch   200  of    533.  Batch took 71.621 secs
#   Batch   300  of    533.  Batch took 107.487 secs
#   Batch   400  of    533.  Batch took 142.505 secs
#   Batch   500  of    533.  Batch took 178.527 secs
#
# Time in seconds: 189.938
# Average accuracy: 0.7491140296018345
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 33.306 secs
#
#   Training Loss: 0.748
#   Validation Loss: 0.732
# ---------------------------------------------
# Epoch 45 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 36.477 secs
#   Batch   200  of    533.  Batch took 77.365 secs
#   Batch   300  of    533.  Batch took 119.275 secs
#   Batch   400  of    533.  Batch took 154.206 secs
#   Batch   500  of    533.  Batch took 190.826 secs
#
# Time in seconds: 202.194
# Average accuracy: 0.7462846477709283
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 33.521 secs
#
#   Training Loss: 0.746
#   Validation Loss: 0.681
# ---------------------------------------------
# Epoch 46 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 36.336 secs
#   Batch   200  of    533.  Batch took 73.041 secs
#   Batch   300  of    533.  Batch took 110.909 secs
#   Batch   400  of    533.  Batch took 154.104 secs
#   Batch   500  of    533.  Batch took 197.503 secs
#
# Time in seconds: 211.533
# Average accuracy: 0.7508724761011346
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 41.384 secs
#
#   Training Loss: 0.75
#   Validation Loss: 0.708
# ---------------------------------------------
# Epoch 47 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 43.109 secs
#   Batch   200  of    533.  Batch took 86.247 secs
#   Batch   300  of    533.  Batch took 129.433 secs
#   Batch   400  of    533.  Batch took 172.621 secs
#   Batch   500  of    533.  Batch took 214.762 secs
#
# Time in seconds: 226.543
# Average accuracy: 0.7465929226599958
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 33.271 secs
#
#   Training Loss: 0.746
#   Validation Loss: 0.745
# ---------------------------------------------
# Epoch 48 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 34.756 secs
#   Batch   200  of    533.  Batch took 69.502 secs
#   Batch   300  of    533.  Batch took 104.31 secs
#   Batch   400  of    533.  Batch took 139.035 secs
#   Batch   500  of    533.  Batch took 173.762 secs
#
# Time in seconds: 185.067
# Average accuracy: 0.7485263297001102
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 33.26 secs
#
#   Training Loss: 0.748
#   Validation Loss: 0.665
# ---------------------------------------------
# Epoch 49 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 34.756 secs
#   Batch   200  of    533.  Batch took 69.491 secs
#   Batch   300  of    533.  Batch took 104.231 secs
#   Batch   400  of    533.  Batch took 139.01 secs
#   Batch   500  of    533.  Batch took 173.766 secs
#
# Time in seconds: 185.061
# Average accuracy: 0.7465026504660651
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 33.204 secs
#
#   Training Loss: 0.747
#   Validation Loss: 0.719
# ---------------------------------------------
# Epoch 50 / 50
# ---------------------------------------------
#   Batch   100  of    533.  Batch took 34.782 secs
#   Batch   200  of    533.  Batch took 69.526 secs
#   Batch   300  of    533.  Batch took 104.271 secs
#   Batch   400  of    533.  Batch took 139.045 secs
#   Batch   500  of    533.  Batch took 173.794 secs
#
# Time in seconds: 185.093
# Average accuracy: 0.7500970193424461
#
# Evaluating...
#   Batch   100  of    115.
#   Eval took 33.233 secs
#
#   Training Loss: 0.75
#   Validation Loss: 0.717
#
# ------------------------
# Finished
# ------------------------

# %%
plt.title('Training and Validation loss by Epoch')
plt.plot(train_losses, 'b-o')
plt.plot(valid_losses, 'r-o')
plt.legend(['Train', 'Validation'])
plt.show()

plt.title('Accuracy by Epoch')
plt.plot(epoch_acc, 'b-o')
plt.show()

# %% [markdown]
# # Testing

# %%
model.eval()
# Out:
# BERT_Arch(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (droput): Dropout(p=0.1, inplace=False)
#   (relu): ReLU()
#   (lstm): LSTM(768, 512, num_layers=2, dropout=0.1, bidirectional=True)
#   (bn): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=1024, out_features=512, bias=True)
#   (bn1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=256, out_features=128, bias=True)
#   (bn3): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc4): Linear(in_features=128, out_features=2, bias=True)
#   (softmax): Softmax(dim=1)
# )

# %% [markdown]
# ## Saving

# %%
output_dir = 'bert_model_save/'

# %%
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %%
print("Saving model to {}".format(output_dir))
# Out:
# Saving model to ./bert_model_save/

# %%
model_to_save = model.module if hasattr(model, 'module') else model

# %%
model_to_save
# Out:
# BERT_Arch(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (droput): Dropout(p=0.1, inplace=False)
#   (relu): ReLU()
#   (lstm): LSTM(768, 512, num_layers=2, dropout=0.1, bidirectional=True)
#   (bn): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=1024, out_features=512, bias=True)
#   (bn1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=256, out_features=128, bias=True)
#   (bn3): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc4): Linear(in_features=128, out_features=2, bias=True)
#   (softmax): Softmax(dim=1)
# )

# %%
torch.save(model_to_save, 'bert_model_save/bert_model.pt')

# %%
path = 'Data/BERT_weights.pt'
model.load_state_dict(torch.load(path))
# Out:
# <All keys matched successfully>

# %%
tokenizer.save_pretrained('bert_model_save/')
# Out:
# ('bert_model_save/tokenizer_config.json',
#  'bert_model_save/special_tokens_map.json',
#  'bert_model_save/vocab.txt',
#  'bert_model_save/added_tokens.json')

# %%
def testing():
    print("\nTesting...")
    t0 = time.time()
    # Evaluation mode
    model.eval()

    # Save predictions
    total_preds = []
    total_labels = []

    # iterate through loader
    for step,batch in enumerate(test_loader):
        if step % 100 == 0 and not step == 0:
            lapsed = time.time() - t0
            print('  Batch {:>5,}  of  {:>5,}. \n  Test took {} secs'.format(step,
                                                                            len(test_loader),
                                                                            round(lapsed, 3)))

        batch = [t.to(device) for t in batch]
        sent_id, _, labels = batch

        with torch.no_grad():
            # model predictions
            preds = model(sent_id)
            pred = F.softmax(preds, dim=1)
            pred = torch.argmax(preds, dim=1)
            total_preds.append(preds)
            total_labels.append(labels)
            
    

    print('-----------------------')
    print('Testing Finished')
    print('-----------------------')
    return total_preds, total_labels

# %%
test_p, labels = testing()
# Out:
# Testing...
#   Batch   100  of    115.
#   Test took 35.913 secs
# -----------------------
# Testing Finished
# -----------------------

# %%
test_p = torch.cat(test_p)
test_preds = torch.argmax(test_p, dim=1)

# %%
labels = [label.detach().cpu().numpy() for label in labels]
test_preds = [test_pred.detach().cpu().numpy() for test_pred in test_preds]

# %%
label_true = np.concatenate(labels)

# %%
print(classification_report(label_true, test_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.75      0.76      7106
#            1       0.77      0.79      0.78      7500
#
#     accuracy                           0.77     14606
#    macro avg       0.77      0.77      0.77     14606
# weighted avg       0.77      0.77      0.77     14606

# %%
con_mat = confusion_matrix(y_true=label_true, y_pred=test_preds)
norm_con_mat = confusion_matrix(y_true=label_true, y_pred=test_preds, normalize='true')

# %%
sns.heatmap(con_mat, annot=True, fmt='g')
plt.show()
sns.heatmap(norm_con_mat, annot=True)
plt.show()

# %%
model.to(device)
for param in model.parameters():
    param.requires_grad = False
model.eval()
# Out:
# BERT_Arch(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (droput): Dropout(p=0.1, inplace=False)
#   (relu): ReLU()
#   (lstm): LSTM(768, 512, num_layers=2, dropout=0.1, bidirectional=True)
#   (bn): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=1024, out_features=512, bias=True)
#   (bn1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=256, out_features=128, bias=True)
#   (bn3): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc4): Linear(in_features=128, out_features=2, bias=True)
#   (softmax): Softmax(dim=1)
# )

# %%
interpreter_unified = UnifiedInformationExplainer(model=model, 
                                 train_dataset=list(train_loader), 
                                 device=device, 
                                 target_layer=14, 
                                 classes=2)

# %%
text_exp, text, label = next(iter(train_loader))[0][0], next(iter(train_loader))[1][0][0].item()

# %%
tokenizer.decode(text_exp, )
# Out:
# '[CLS] it starts out really slow, but is all tied together in just a few words. the ending is great, so far. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]'

# %%
explanation_unified = interpreter_unified.explain_local(text, true_label)
